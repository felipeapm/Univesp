# %%
# Instalando o Arrow (caso você rode no Google Colab)
# !pip install arrow
# Out:
# Requirement already satisfied: arrow in /usr/local/lib/python3.7/dist-packages (1.0.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from arrow) (2.8.1)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from arrow) (3.7.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.0->arrow) (1.15.0)

# %%
# Lendo as bibliotecas
from oauthlib.oauth2 import BackendApplicationClient
from requests_oauthlib import OAuth2Session
import numpy as np
import pandas as pd
import arrow
from pandas import json_normalize
import json
import glob
import matplotlib.pyplot as plt

# %%
# Definindo a funcoes para uso da API da plataforma
def get_data(application,guid,timestamp_init,timestamp_final):
    result = []
    i = 0
    lastlen=10000
    while timestamp_init < timestamp_final:
        stats = oauth.get("https://api.demo.konkerlabs.net/v1/{}/incomingEvents?q=device:{} timestamp:>{}&sort=oldest&limit=10000".format(application,guid, timestamp_init)).json()['result']
        if (len(stats)<2) and (lastlen<10000) :
            break
        timestamp_init = stats[-1]['timestamp']
        result.extend(stats)
        lastlen = len(stats)
        print(timestamp_init)
    return result

def list_devices(oauth):
    global base_api
    devices = oauth.get("https://api.demo.konkerlabs.net/v1/{}/devices/?size=5000".format(application)).json()['result']
    return devices

# %%
# Inserindo os dados da conta na plataforma (importante não passar esse notebook para pessoas externas)
base_api = 'https://api.demo.konkerlabs.net'
application = 'univesp'
username = "data@univesp.br"
password = 'FYCzR3JAH6qn6xu6'

# %%
# Autenticando e pegando o token de acesso a conta
client = BackendApplicationClient(client_id=username)
oauth = OAuth2Session(client=client)
token = oauth.fetch_token(token_url='{}/v1/oauth/token'.format(base_api),client_id=username,client_secret=password)

# %%
# Listando os dispositivos dessa conta.
# Cada dispositivo possuí um sensor DHT22 e está localizado em um dos polos da Univesp.
# Existem dispositivos que não tem dados, pois nunca foram ligados, bem como alguns com dados intermitentes, que funcionam
# por um período e estão desligados por outros.
dev_list = list_devices(oauth)

# %%
# Vamos olhar agora os metadados de dispositivos.
dev_list
# Out:
# [{'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '60e55023-91a9-4e85-b49c-e732b5e69318',
#   'id': 'S8V0200A0B4B7',
#   'locationName': 'default',
#   'name': 'S8V0200A0B4B7-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'a5fee9c9-5cf6-4e60-9349-7476a702cf74',
#   'id': 'S8V0200A43F4B',
#   'locationName': 'default',
#   'name': 'S8V0200A43F4B-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '893985e8-77a8-482b-bc0d-04d22b4752e7',
#   'id': 'S8V0200839C0F',
#   'locationName': 'default',
#   'name': 'S8V0200839C0F-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '2663ba7f-12bc-4907-8239-17651b6896ec',
#   'id': 'S8V02009B1E56',
#   'locationName': 'default',
#   'name': 'S8V02009B1E56-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'daa1368b-a17e-408c-a282-e7cb40ec6bc5',
#   'id': 'S8V02000BF0CB',
#   'locationName': 'default',
#   'name': 'S8V02000BF0CB-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'bda99e10-e470-4168-b1b6-297726d62f49',
#   'id': 'S8V020018A94C',
#   'locationName': 'default',
#   'name': 'S8V020018A94C-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'b3dee677-1f8b-4044-851b-dfe1db7ea357',
#   'id': 'S8V02001B1901',
#   'locationName': 'default',
#   'name': 'S8V02001B1901-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'ebbe4e45-0f5e-4d31-922a-590ac97153d3',
#   'id': 'S8V02002BB926',
#   'locationName': 'default',
#   'name': 'S8V02002BB926-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'afb42550-136d-427c-9a49-1024502dc20f',
#   'id': 'S8V0200D7D441',
#   'locationName': 'default',
#   'name': 'S8V0200D7D441-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '62094131-6daa-4766-87fb-7065d3363a0a',
#   'id': 'S8V0200F213DC',
#   'locationName': 'default',
#   'name': 'S8V0200F213DC-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '989398b6-0b8b-40a6-8255-6d20c2c897d4',
#   'id': 'S8V0200FCAD56',
#   'locationName': 'default',
#   'name': 'S8V0200FCAD56-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '743c5e8a-66f4-4f3e-b301-7323c3faebcd',
#   'id': 'S8V0200FC5078',
#   'locationName': 'default',
#   'name': 'S8V0200FC5078-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '7ecf6bb8-4fef-44f7-ae15-74585e7ab6b0',
#   'id': 'S8V0200111F91',
#   'locationName': 'default',
#   'name': 'S8V0200111F91-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '764a5377-62cb-403a-a9d4-5cbc26b4d4d0',
#   'id': 'S8V020017F09D',
#   'locationName': 'default',
#   'name': 'S8V020017F09D-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'bb28ec96-99cd-4c6a-8096-7e3429e21b6e',
#   'id': 'S8V0200070440',
#   'locationName': 'default',
#   'name': 'S8V0200070440-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'faa758a5-7772-4063-9fa1-87373bee6cd2',
#   'id': 'S8V0200D5F32D',
#   'locationName': 'default',
#   'name': 'S8V0200D5F32D-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '287d9e9a-ca09-46d6-b717-1787edd4e13a',
#   'id': 'S8V0200A0B484',
#   'locationName': 'default',
#   'name': 'S8V0200A0B484-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '0303f05c-c1b9-4989-836c-8e1c9e7c3e58',
#   'id': 'S8V0200FCEF35',
#   'locationName': 'default',
#   'name': 'S8V0200FCEF35-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '5fb50477-efb0-4689-be66-4465c4df954d',
#   'id': 'S8V0200D5E70E',
#   'locationName': 'default',
#   'name': 'S8V0200D5E70E-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '76bb89c6-9e62-4a6d-a18f-d3efdcf66ec1',
#   'id': 'S8V0200D2445B',
#   'locationName': 'default',
#   'name': 'S8V0200D2445B-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '583f0027-a2f5-4cb1-ae13-01a5d2bb324d',
#   'id': 'S8V0200D33437',
#   'locationName': 'default',
#   'name': 'S8V0200D33437-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '85e467ac-36b4-48d9-b6a9-f1a2251e78d6',
#   'id': 'S8V0200D016E4',
#   'locationName': 'default',
#   'name': 'S8V0200D016E4-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '8d93d28e-0bb1-45cb-8563-2fdb0b55fa91',
#   'id': 'S8V0200CC3C0F',
#   'locationName': 'default',
#   'name': 'S8V0200CC3C0F-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'd40bcda9-93d2-4aa5-ad71-fe39e5833d7b',
#   'id': 'S8V020014F96F',
#   'locationName': 'default',
#   'name': 'S8V020014F96F-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'bd7d0778-dd03-475b-8743-4222f5bf50bf',
#   'id': 'S8V02000F627D',
#   'locationName': 'default',
#   'name': 'S8V02000F627D-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'e4cb2c17-4351-4fa2-b139-b753cc610b3c',
#   'id': 'S8V0200DA00CE',
#   'locationName': 'default',
#   'name': 'S8V0200DA00CE-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '499e5f4c-3a05-4470-baa0-36d63e43599e',
#   'id': 'S8V020016A479',
#   'locationName': 'default',
#   'name': 'S8V020016A479-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'a91344b5-ab1b-4b30-b29d-d67108f526d2',
#   'id': 'S8V0200A5E070',
#   'locationName': 'default',
#   'name': 'S8V0200A5E070-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'b9066d5c-96e7-4da6-b356-29b4e86b2f86',
#   'id': 'S8V0200A0687F',
#   'locationName': 'default',
#   'name': 'S8V0200A0687F-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'b500b105-a2d5-4897-a8cc-af885717f60a',
#   'id': 'S8V0200947BE1',
#   'locationName': 'default',
#   'name': 'S8V0200947BE1-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'f3c06748-0f9b-4dd2-bbd2-75d4edeb6d07',
#   'id': 'S8V020011EA51',
#   'locationName': 'default',
#   'name': 'S8V020011EA51-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'ea59f6c8-6ca4-4c1e-b9eb-5b5def499da4',
#   'id': 'S8V02000D3DC3',
#   'locationName': 'default',
#   'name': 'S8V02000D3DC3-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'a4902e53-c382-4689-ba90-1bebc7ad3ba7',
#   'id': 'S8V0200DDB14D',
#   'locationName': 'default',
#   'name': 'S8V0200DDB14D-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '34abab96-b6ff-462d-a8b9-8c4c86616f64',
#   'id': 'S8V0200C78E8C',
#   'locationName': 'default',
#   'name': 'S8V0200C78E8C-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'b26849cb-c935-40f4-8799-063888bd9693',
#   'id': 'S8V0200A325F3',
#   'locationName': 'default',
#   'name': 'S8V0200A325F3-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'dacadb76-3614-45f3-be4a-81f3807f1c35',
#   'id': 'S8V020086FE52',
#   'locationName': 'default',
#   'name': 'S8V020086FE52-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '3c09b2c2-1e15-4221-924d-1936472e0b3a',
#   'id': 'S8V0200D52D21',
#   'locationName': 'default',
#   'name': 'S8V0200D52D21-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '68db6a10-0815-4552-92b7-1ffa00650a9e',
#   'id': 'S8V0200FE0510',
#   'locationName': 'default',
#   'name': 'S8V0200FE0510-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '3c146cd6-fafa-46b8-ad12-ad2c9e9cb103',
#   'id': 'S8V02009E9885',
#   'locationName': 'default',
#   'name': 'S8V02009E9885-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'cc10aaaa-4e13-456e-9aac-b714c19e6cb3',
#   'id': 'S8V0200D61DFF',
#   'locationName': 'default',
#   'name': 'S8V0200D61DFF-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'aeeea730-6686-400d-a238-ef278b4d15a7',
#   'id': 'S8V02000ED393',
#   'locationName': 'default',
#   'name': 'S8V02000ED393-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '66e639ba-6953-4a43-8b8c-18272617d2f9',
#   'id': 'S8V020000E17E',
#   'locationName': 'default',
#   'name': 'S8V020000E17E-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '570ede9d-2af9-4a48-96c5-62ef8964fbee',
#   'id': 'S8V0200D5AA98',
#   'locationName': 'default',
#   'name': 'S8V0200D5AA98-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '2f2a48a9-762d-4a47-8dd2-c03367b74f8d',
#   'id': 'S8V0200A64336',
#   'locationName': 'default',
#   'name': 'S8V0200A64336-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '3f09b591-e058-4895-9566-d93ed15b8b39',
#   'id': 'S8V0200A1C609',
#   'locationName': 'default',
#   'name': 'S8V0200A1C609-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '66db05ef-9785-469a-8732-d4c23610635b',
#   'id': 'S8V0200038884',
#   'locationName': 'default',
#   'name': 'S8V0200038884-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'f396432f-71f1-4609-ad7e-e6b6f54c8c99',
#   'id': 'S8V02000B3FBE',
#   'locationName': 'default',
#   'name': 'S8V02000B3FBE-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '76727a73-de03-476c-8dda-a94016e4d078',
#   'id': 'S8V0200CB28BB',
#   'locationName': 'default',
#   'name': 'S8V0200CB28BB-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': '187abf17-256f-4a7a-a0ac-91d0372f1075',
#   'id': 'S8V0200D8C815',
#   'locationName': 'default',
#   'name': 'S8V0200D8C815-DHT22',
#   'tags': []},
#  {'active': True,
#   'debug': False,
#   'description': 'DHT22',
#   'deviceModelName': 'S8V02',
#   'guid': 'c83cffee-5057-4177-ae48-fee8a822a38a',
#   'id': 'S8V0200D57915',
#   'locationName': 'default',
#   'name': 'S8V0200D57915-DHT22',
#   'tags': []}]

# %%
# Todos os dispositivos são identificados na plataforma pelo seu guid.
# Essa é a informação que você deve usar para baixar os dados de um dispositivo único
# Vamos examinar o dispositivo S8V0200A0B4B7 que está em São Paulo (-23.554597,-46.7333)
guid = '60e55023-91a9-4e85-b49c-e732b5e69318'

# %%
# Vamos dar uma olhada nos dados desse dispositivo no mês de junho e julho
data_inicial = '2020-06-01T00:00:00.000000'
data_final = '2020-08-01T00:00:00.000000'
dev_data = get_data(application, guid, data_inicial , data_final)
stats_df = json_normalize(dev_data).set_index('timestamp')
stats_df.index = pd.to_datetime(stats_df.index)
stats_df.index = stats_df.index.tz_convert('America/Sao_Paulo')
# Out:
# 2020-06-06T18:02:45.104Z
# 2020-06-12T11:02:49.573Z
# 2020-06-19T09:46:43.374Z
# 2020-07-16T21:40:49.774Z
# 2020-08-09T11:32:24.295Z

# %%
stats_df
# Out:
#                                          ingestedTimestamp  ... payload
# timestamp                                                   ...
# 2020-05-31 21:00:29.130000-03:00  2020-06-01T00:00:29.130Z  ...     NaN
# 2020-05-31 21:01:31.232000-03:00  2020-06-01T00:01:31.232Z  ...     NaN
# 2020-05-31 21:02:29.123000-03:00  2020-06-01T00:02:29.123Z  ...     NaN
# 2020-05-31 21:02:40.755000-03:00  2020-06-01T00:02:40.755Z  ...     NaN
# 2020-05-31 21:03:29.123000-03:00  2020-06-01T00:03:29.123Z  ...     NaN
# ...                                                    ...  ...     ...
# 2020-08-09 08:28:24.291000-03:00  2020-08-09T11:28:24.291Z  ...     NaN
# 2020-08-09 08:29:24.291000-03:00  2020-08-09T11:29:24.291Z  ...     NaN
# 2020-08-09 08:30:26.920000-03:00  2020-08-09T11:30:26.920Z  ...     NaN
# 2020-08-09 08:31:24.300000-03:00  2020-08-09T11:31:24.300Z  ...     NaN
# 2020-08-09 08:32:24.295000-03:00  2020-08-09T11:32:24.295Z  ...     NaN
#
# [50000 rows x 12 columns]

# %%
# Vamos agora examinar os dados do dispositivo:
stats_df.groupby(['incoming.channel']).count()
# Out:
#                   ingestedTimestamp  ...  payload
# incoming.channel                     ...
# _health                       19384  ...        0
# _networks                      1615  ...     1615
# data                          29001  ...        0
#
# [3 rows x 11 columns]

# %%
# Os dispositivos tem 3 canais de dados independentes. 
# _health: envia os dados com relação a rede a qual o dispositivo está conectado e sobre os erros de leitura e envio dos dados;
# _networks: envia os dados com relação as redes wifi visíveis para o dispositivo (usado para reconstrução da posição);
# data: envia os dados de temperatura e umidade medidos pelo DHT22.
# Esses dados são gerados por processos distintos rodando no ESP8266, logo podem falhar de forma independente.
# Você vai notar que o DHT22 tem um índice de falha relativamente alto os dados dele não vão estar disponíveis em todo o intervalo.

# %%
# Vamos agora dar uma olhada nos dados de temperatura e umidade
fig, ax1 = plt.subplots(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
plt.gca().xaxis_date('America/Sao_Paulo')
plt.rcParams['timezone'] = 'America/Sao_Paulo'
plt.title('Temperatura e umidade do dispositivo S8V0200A0B4B7', size=32,y=1.02)
ax1.plot(stats_df[stats_df['incoming.channel']=='data']['payload.temperature'], color='red',alpha=1, linewidth=1)
ax1.set_ylabel('Temperatura [$^\circ$C]', size=24, color = 'red')
ax1.set_xlabel('Data', size=24)
plt.grid()
for tl in ax1.get_yticklabels():
    tl.set_color('r')
    fig.tight_layout()
labels = ax1.get_xticklabels()
ax2 = ax1.twinx()
ax2.plot(stats_df[stats_df['incoming.channel']=='data']['payload.humidity'], color='blue', linewidth=1)
ax2.set_ylabel('Umidade [%]', size=24, color = 'blue')
for tl in ax2.get_yticklabels():
    tl.set_color('b')
fig.tight_layout()
labels = ax1.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=22)
plt.show()

# %%
# No gráfico acima é possível observar um gap nos dados de mais de 30 dias.
# Vamos olhar apenas as primeiras semanas do gráfico:

# Vamos agora dar uma olhada nos dados de temperatura e umidade
fig, ax1 = plt.subplots(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
plt.gca().xaxis_date('America/Sao_Paulo')
plt.rcParams['timezone'] = 'America/Sao_Paulo'
plt.title('Temperatura e umidade do dispositivo S8V0200A0B4B7', size=32,y=1.02)
ax1.plot(stats_df[stats_df['incoming.channel']=='data']['payload.temperature'][:20000], color='red',alpha=1, linewidth=1)
ax1.set_ylabel('Temperatura [$^\circ$C]', size=24, color = 'red')
ax1.set_xlabel('Data', size=24)
plt.grid()
for tl in ax1.get_yticklabels():
    tl.set_color('r')
    fig.tight_layout()
labels = ax1.get_xticklabels()
ax2 = ax1.twinx()
ax2.plot(stats_df[stats_df['incoming.channel']=='data']['payload.humidity'][:20000], color='blue', linewidth=1)
ax2.set_ylabel('Umidade [%]', size=24, color = 'blue')
for tl in ax2.get_yticklabels():
    tl.set_color('b')
fig.tight_layout()
labels = ax1.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=22)
plt.show()

# %% [markdown]
# # ANALISE ESTATISTICA
#
# Análise dos dados com medidas estatísticas descritivas simples (como moda, média, mediana e desvio padrão), utilizando os conceitos de ciência de dados para extração de conhecimento.
#
# É preciso:
# * Saber coletar, extrair, analisar, classificar, examinar e comparar todos os dados a nossa disposição.
#
# * Visa a extração de conhecimento, detecção de padrões e/ou obtenção de insights para possíveis tomadas de decisão.

# %%
data_process = pd.DataFrame()
data_process['temperatura'] = stats_df[stats_df['incoming.channel']=='data']['payload.temperature']
data_process['umidade'] = stats_df[stats_df['incoming.channel']=='data']['payload.humidity']
data_process
# Out:
#                                   temperatura  umidade
# timestamp
# 2020-05-31 21:00:29.130000-03:00         22.1     44.3
# 2020-05-31 21:01:31.232000-03:00         22.0     44.2
# 2020-05-31 21:02:29.123000-03:00         22.0     44.2
# 2020-05-31 21:03:29.123000-03:00         22.0     44.2
# 2020-05-31 21:04:29.119000-03:00         22.0     44.3
# ...                                       ...      ...
# 2020-08-09 08:28:24.291000-03:00         24.1     51.7
# 2020-08-09 08:29:24.291000-03:00         24.1     51.6
# 2020-08-09 08:30:26.920000-03:00         24.1     51.6
# 2020-08-09 08:31:24.300000-03:00         24.1     51.7
# 2020-08-09 08:32:24.295000-03:00         24.1     51.7
#
# [29001 rows x 2 columns]

# %% [markdown]
# ### **Analise Analítica**

# %%
data_process.describe()
# Out:
#         temperatura       umidade
# count  29001.000000  29001.000000
# mean      24.573697     54.827358
# std        1.319867      5.145520
# min       18.800000     36.300000
# 25%       23.700000     51.600000
# 50%       24.600000     55.900000
# 75%       25.500000     59.000000
# max       27.700000     63.200000

# %% [markdown]
# **Conclusões:**
# - Comportamento dos dados.
# - Valores máximos e mínimos.

# %%
data_process.sort_values(by=['umidade'], ascending=False).head(5)
# Out:
#                                   temperatura  umidade
# timestamp
# 2020-06-06 06:56:33.230000-03:00         23.8     63.2
# 2020-06-06 06:57:33.244000-03:00         23.9     63.2
# 2020-06-06 06:54:33.227000-03:00         23.8     63.2
# 2020-06-06 06:55:33.226000-03:00         23.8     63.2
# 2020-06-07 05:07:33.981000-03:00         24.8     63.1

# %%
data_process.groupby([data_process.index.month]).describe()
# data_process.groupby(['temperatura']).describe()
# Out:
#           temperatura                             ... umidade
#                 count       mean       std   min  ...     25%   50%   75%   max
# timestamp                                         ...
# 5               180.0  21.671111  0.216753  21.3  ...    44.7  45.4  46.0  46.6
# 6             26144.0  24.636681  1.309702  20.1  ...    52.5  56.4  59.2  63.2
# 8              2677.0  24.153754  1.155845  18.8  ...    43.3  49.5  52.0  56.4
#
# [3 rows x 16 columns]

# %% [markdown]
# **Conclusões:**
# 1. O mês mais menor temperatura média foi Maio.
# 2. O mês com maior umidade média foi Junho.
# 3. O mês com a temperatura mais estável foi Maio.

# %% [markdown]
# ### **Analise Grafica**

# %%
data_process.boxplot()

# %%
import seaborn as sns
fig = sns.kdeplot(df['temperatura'], shade=True, color="r")
fig = sns.kdeplot(df['umidade'], shade=True, color="b")
plt.show()

# %%
import seaborn as sns

df = data_process.copy()
sns.violinplot(data=df)
plt.title("Violin plot", loc="left")
plt.show()
