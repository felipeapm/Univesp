# %%
import csv
nome_arquivo = "Pasta1.csv"
def qual_nome_funcao():    
    with open(nome_arquivo) as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        csv_reader.__next__()
        for row in csv_reader:
            print(row[0])
qual_nome_funcao()
# Out:
# a2;b2;c2;d2;e2;f2
# a3;b3;c3;d3;e3;f3
# a4;b4;c4;d4;e4;f4
# a5;b5;c5;d5;e5;f5
# a6;b6;c6;d6;e6;f6
